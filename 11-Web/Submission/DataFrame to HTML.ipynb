# %%
import pandas as pd
import csv
from IPython.display import HTML
filepath = 'Resource/WeatherData.csv'
df = pd.read_csv(filepath)
df
# Out:
#                              City      Lat       Lng  Max_Temp  Humidity  \
# 0                   Sioux Lookout  50.1001  -91.9170    -16.53      76.0
# 1                        Sterling  39.0062  -77.4286     33.71      78.0
# 2                         Ushuaia -54.8000  -68.3000     47.86      71.0
# 3                 Arraial do Cabo -22.9661  -42.0278     75.81      87.0
# 4                   Alta Floresta  -9.8756  -56.0861     71.47      96.0
# ..                            ...      ...       ...       ...       ...
# 650                      Brekstad  63.6870    9.6654     35.20      80.0
# 651       Gizo Government Station  -8.1030  156.8419     86.11      71.0
# 652                        Kovdor  67.5662   30.4758     14.94      89.0
# 653  Presidencia Roque Sáenz Peña -26.7852  -60.4388     72.09      97.0
# 654                    Palm Coast  29.5850  -81.2078     70.63      72.0
#
#      Cloudiness  Wind_Speed Country          Date  Pressure
# ...

# %%
result = df.to_html()
print(result)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max_Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind_Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Pressure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Sioux Lookout</td>
#       <td>50.1001</td>
#       <td>-91.9170</td>
#       <td>-16.53</td>
#       <td>76.0</td>
#       <td>0.0</td>
#       <td>2.30</td>
#       <td>CA</td>
#       <td>1.644030e+09</td>
#       <td>1026.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Sterling</td>
#       <td>39.0062</td>
#       <td>-77.4286</td>
#       <td>33.71</td>
#       <td>78.0</td>
#       <td>100.0</td>
#       <td>1.99</td>
#       <td>US</td>
#       <td>1.644029e+09</td>
#       <td>1020.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
text_file = open("data.html", "w")
text_file.write(result)
text_file.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4228/3389245133.py in <module>
#       1 text_file = open("data.html", "w")
# ----> 2 text_file.write(result)
#       3 text_file.close()
#
# ~\Downloads\Anaconda\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u0101' in position 15658: character maps to <undefined>
